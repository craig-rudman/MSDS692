# %% [markdown]
# # Synthesis
#
# **Status: intentionally empty.**
#
# The previous draft report has been cleared. This notebook will be rebuilt as the full draft report once the analytical story is decided and `05_analysis.ipynb` is rebuilt around it.
